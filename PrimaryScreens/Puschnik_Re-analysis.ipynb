# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import gpplot as gpp
import anchors
import core_functions as fns
from poola import core as pool

gpp.set_aesthetics(palette='Set2')

# %% [markdown]
# ## Functions

# %%
#Process data
def reformat_pDNA(df):
    '''
    Reformat pDNA 
    Input: df: original Sanjana pDNA reads  
    '''
    #sgRNA: HgLibA_00001 --> A1BG.1-A 
    new_df = df.copy()
    new_df = new_df.rename(columns = {'Guide': 'old_Guide', 'Reads':'pDNA'})
    new_guide_list = []
    gene_count = 1
    prev_gene = ''
    dummyguide_no = 1
    for i, row in enumerate(new_df.loc[:,'old_Guide']):
        gene = new_df.loc[i, 'Gene Symbol']
        if 'NonTargeting' in gene:
            gene = 'dummyguide'
            new_df.loc[i, 'Gene Symbol'] = 'dummyguide_' + str(dummyguide_no)
            dummyguide_no +=1
        if gene == prev_gene:
            gene_count +=1
        else:
            gene_count = 1
            
        guide_no = gene_count
        library = row.split('_')[0][-1]
        new_guide = gene+'.'+str(guide_no) + '-' + library
        new_guide_list.append(new_guide) 
        prev_gene = gene

    new_df['Guide'] = new_guide_list
    new_df = new_df.drop('old_Guide', axis = 1)
    new_df = new_df[['Guide', 'Gene Symbol', 'pDNA']]
    return new_df

def get_grouped_pseudogenes(df, control_name):
    '''
    Inputs:
    1. df: guide-gene annotations dataframe 
    2. control_name: list containing substrings that identify controls 
    Output:
    1. grouped_genes: controls grouped into pseudogenes with 6 randomly selected controls 
        (3 from Library A and 3 from Library B)
    '''
    #check if ungrouped df has unique identifiers for each control
    for control in control_name:
        control_condition = (df['Gene Symbol'].eq(control))
        control_rows = df[control_condition]
        #if all controls have same Gene Symbol
        ungrouped_df = df.copy()
            
        LibA_ungrouped_genes = ungrouped_df[ungrouped_df['Guide'].str.contains('-A')].dropna()
        LibA_grouped_genes = pool.group_pseudogenes(LibA_ungrouped_genes[['Guide', 'Gene Symbol']], pseudogene_size=3, gene_col='Gene Symbol', control_regex = [control])

        LibB_ungrouped_genes = ungrouped_df[ungrouped_df['Guide'].str.contains('-B', na=False)].dropna()
        LibB_grouped_genes = pool.group_pseudogenes(LibB_ungrouped_genes[['Guide', 'Gene Symbol']], pseudogene_size=3, gene_col='Gene Symbol', control_regex = [control])

        grouped_genes = pd.concat([LibA_grouped_genes, LibB_grouped_genes])
            
        return grouped_genes

def match_pseudogenes(df, guide_mapping, control_name):
    '''
    Inputs:
    1. df: reads dataframe
    2. guide_mapping: guide-gene annotation dataframe
    3. control_name: list containing substrings that identify controls
    Outputs:
    1. grouped_df: reads dataframe with controls grouped into pseudogenes 
    '''
    grouped_genes = get_grouped_pseudogenes(guide_mapping, control_name)
    grouped_df = pd.merge(grouped_genes, df, on = 'Guide', how = 'outer', suffixes = ['', '_old'])
    grouped_df.loc[:,'Gene Symbol'] = grouped_df.loc[:,'Gene Symbol'].fillna(grouped_df['Gene Symbol_old'])
    grouped_df = grouped_df.drop('Gene Symbol_old', axis = 1)

    return grouped_df

# %% [markdown]
# ## Data Summary
#
# * Wang et al.
# * Cell line: Huh7.5.1
# * Library: GeCKOv2

# %%
# Reads from GEO Submission GSE175666 
reads = pd.read_excel('Data/GSE175666_Huh751_GeCKOv2_Puschnik.xlsx', sheet_name = 'Huh751_GeCKOv2_genomewide_reads')
reads
# Out:
#               Guide Gene Symbol   pDNA  \
# 0          A1BG.1-A        A1BG  467.0
# 1          A1BG.2-A        A1BG  417.0
# 2          A1BG.3-A        A1BG  981.0
# 3          A1CF.1-A        A1CF  170.0
# 4          A1CF.2-A        A1CF  599.0
# ...             ...         ...    ...
# 123436  ZBED1_X.2-B         NaN    NaN
# 123437  ZBED1_X.3-B         NaN    NaN
# 123438  ZBED1_Y.1-B         NaN    NaN
# 123439  ZBED1_Y.2-B         NaN    NaN
# 123440  ZBED1_Y.3-B         NaN    NaN
#
#         Huh751_ACE2-IRES-TMPRSS2_Gecko_control  \
# 0                                          867
# 1                                          538
# 2                                         1801
# 3                                          276
# 4                                          674
# ...                                        ...
# 123436                                    2740
# 123437                                    3494
# 123438                                    2794
# 123439                                    2740
# 123440                                    3494
#
#         Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2
# 0                                        241
# 1                                        475
# 2                                        216
# 3                                        104
# 4                                         66
# ...                                      ...
# 123436                                  1215
# 123437                                  2886
# 123438                                  1071
# 123439                                  1215
# 123440                                  2886
#
# [123441 rows x 5 columns]

# %%
#Calculate lognorm

cols = reads.columns[2:].to_list() #reads columns are 3rd and 4th in df
lognorms = fns.get_lognorm(reads.dropna(), cols = cols)
lognorms
# Out:
#                    Guide     Gene Symbol  pDNA_lognorm  \
# 0               A1BG.1-A            A1BG      2.960342
# 1               A1BG.2-A            A1BG      2.819023
# 2               A1BG.3-A            A1BG      3.930627
# 3               A1CF.1-A            A1CF      1.794610
# 4               A1CF.2-A            A1CF      3.278038
# ...                  ...             ...           ...
# 123196  dummyguide.995-B  dummyguide_253      4.076868
# 123197  dummyguide.996-B  dummyguide_181      3.828129
# 123198  dummyguide.997-B   dummyguide_63      3.469914
# 123199  dummyguide.998-B  dummyguide_154      4.663548
# 123200  dummyguide.999-B  dummyguide_112      2.941372
#
#         Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lognorm  \
# 0                                             2.838099
# 1                                             2.268057
# 2                                             3.784175
# 3                                             1.564637
# 4                                             2.531461
# ...                                                ...
# 123196                                        2.842386
# 123197                                        2.859410
# 123198                                        3.804095
# 123199                                        3.825189
# 123200                                        1.809123
#
#         Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lognorm
# 0                                           2.344720
# 1                                           3.176441
# 2                                           2.219221
# 3                                           1.464929
# 4                                           1.082185
# ...                                              ...
# 123196                                      2.433293
# 123197                                      2.989217
# 123198                                      3.435384
# 123199                                      3.237270
# 123200                                      2.290840
#
# [123201 rows x 5 columns]

# %% [markdown]
# ## Quality Control
# ### Population Distributions

# %%
#Calculate log-fold change relative to pDNA
target_cols = list(lognorms.columns[-2:])
pDNA_lfc = fns.calculate_lfc(lognorms,target_cols)
#Plot population distributions of log-fold changes 
fns.lfc_dist_plot(pDNA_lfc, initial_id = 'control', res_id = 'SARS', filename = 'Huh751_GeCKOv2')

# %% [markdown]
# ### Control Distributions

# %%
fns.control_dist_plot(pDNA_lfc, initial_id = 'control', res_id = 'SARS', control_name=['dummyguide'], filename = 'Huh751_GeCKOv2')

# %% [markdown]
# ### ROC-AUC

# %%
ess_genes, non_ess_genes = fns.get_gene_sets()

tp_genes = ess_genes.loc[:, 'Gene Symbol'].to_list()

fp_genes = non_ess_genes.loc[:, 'Gene Symbol'].to_list()

control_col = [col for col in pDNA_lfc.columns if 'control' in col]

roc_auc, roc_df = pool.get_roc_aucs(pDNA_lfc, tp_genes, fp_genes, gene_col = 'Gene Symbol', score_col=control_col)    

fig,ax=plt.subplots(figsize=(6,6))
ax=sns.lineplot(data=roc_df, x='fpr',y='tpr', ci=None, label = 'Control,' + str(round(roc_auc,2)))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.title('ROC-AUC')
plt.xlabel('False Positive Rate (non-essential)')
plt.ylabel('True Positive Rate (essential)')
# Out:
# Text(0, 0.5, 'True Positive Rate (essential)')

# %% [markdown]
# ## Gene-level analysis

# %% [markdown]
# ### Residual z-scores

# %%
#Calculate z-scores of lfc residuals
lfc_df = pDNA_lfc.copy().drop(['Gene Symbol'], axis = 1)
lfc_df = lfc_df.dropna()

guide_residuals_lfcs, all_model_info, model_fit_plots = fns.run_guide_residuals(lfc_df, initial_id = 'control', res_id = 'SARS')

guide_mapping = pDNA_lfc[['Guide', 'Gene Symbol']]

gene_residuals = anchors.get_gene_residuals(guide_residuals_lfcs, guide_mapping)
gene_residuals
# Out:
#                                    modified  \
# 0  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc
#
#                                   unperturbed
# 0  Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc
#                                       condition  Gene Symbol  guides  \
# 0      Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc         A1BG       6
# 1      Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc         A1CF       6
# 2      Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc          A2M       6
# 3      Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc        A2ML1       6
# 4      Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc      A3GALT2       6
# ...                                         ...          ...     ...
# 21206  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc   hsa-mir-95       4
# 21207  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc   hsa-mir-96       4
# 21208  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc   hsa-mir-98       4
# 21209  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc  hsa-mir-99a       4
# 21210  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc  hsa-mir-99b       4
#
#         avg_lfc  avg_lfc_reference  residual_zscore   p_value    fdr_bh
# 0     -0.388630          -0.078396        -0.051673  0.958789  0.998631
# 1     -0.570074          -0.198043        -0.208600  0.834761  0.994389
# 2     -0.173488           0.009172         0.276440  0.782210  0.987715
# 3      0.990566           0.088141         3.266771  0.001088  0.232647
# 4      0.670618           0.355756         1.596300  0.110422  0.848085
# ...         ...                ...              ...       ...       ...
# 21206  0.116153           0.560040        -0.417921  0.676005  0.978077
# 21207  0.389002           0.098076         1.282439  0.199689  0.897070
# 21208 -0.594006           0.133466        -1.001658  0.316509  0.924095
# 21209  0.495609           0.713639         0.070137  0.944085  0.998552
# 21210 -0.483007           0.347726        -1.261964  0.206962  0.899457
#
# [21211 rows x 8 columns]

# %%
gene_residual_sheet= fns.format_gene_residuals(gene_residuals, guide_min = 5, guide_max = 7)
guide_residual_sheet = pd.merge(guide_mapping, guide_residuals_lfcs, on = 'Guide', how = 'outer')
guide_residual_sheet
# Out:
# ['Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc']
#                    Guide     Gene Symbol  \
# 0               A1BG.1-A            A1BG
# 1               A1BG.2-A            A1BG
# 2               A1BG.3-A            A1BG
# 3               A1CF.1-A            A1CF
# 4               A1CF.2-A            A1CF
# ...                  ...             ...
# 123196  dummyguide.995-B  dummyguide_253
# 123197  dummyguide.996-B  dummyguide_181
# 123198  dummyguide.997-B   dummyguide_63
# 123199  dummyguide.998-B  dummyguide_154
# 123200  dummyguide.999-B  dummyguide_112
#
#                                        condition  residual  residual_z  \
# 0       Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc -0.196831   -0.221334
# 1       Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc  1.220076    1.371961
# 2       Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc -1.267408   -1.425186
# 3       Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc  0.201145    0.226185
# 4       Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc -1.132375   -1.273342
# ...                                          ...       ...         ...
# 123196  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc -0.083471   -0.093862
# 123197  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc  0.451410    0.507606
# 123198  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc -0.094189   -0.105915
# 123199  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc -0.268922   -0.302400
# 123200  Huh751_ACE2-IRES-TMPRSS2_Gecko_SARS2_lfc  0.805994    0.906331
#
#                                        unperturbed       lfc  lfc_reference
# 0       Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -0.615622      -0.122244
# 1       Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc  0.357418      -0.550966
# 2       Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -1.711406      -0.146452
# 3       Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -0.329681      -0.229973
# 4       Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -2.195854      -0.746578
# ...                                            ...       ...            ...
# 123196  Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -1.643576      -1.234482
# 123197  Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -0.838912      -0.968719
# 123198  Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -0.034530       0.334181
# 123199  Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -1.426278      -0.838359
# 123200  Huh751_ACE2-IRES-TMPRSS2_Gecko_control_lfc -0.650531      -1.132248
#
# [123201 rows x 8 columns]
